# %%
import pandas as pd

# %%
import pickle

# %%
with open('result/testcif/ABW/nb_ABW.pickle','rb') as f:
    nn_data=pickle.load(f)
nn_data
# Out:
# {0: [['Si1', 1.0, 0.0, 4.0202856, 5.706639],
#   [16, 'O1', 0.0, 2.46825, 5.282171],
#   [10, 'O1', -1.3135, 4.34412, 6.5775],
#   [14, 'O1', 0.0, 4.9365, 4.385],
#   [12, 'O1', 1.3135, 4.34412, 6.5775]],
#  1: [['Si1', 1.0, 0.0, 0.9162144, 5.706639],
#   [23, 'O1', 0.0, 0.0, 4.385],
#   [11, 'O1', -1.3135, 0.59238, 6.5775],
#   [16, 'O1', 0.0, 2.46825, 5.282171],
#   [13, 'O1', 1.3135, 0.59238, 6.5775]],
#  2: [['Si1', 1.0, 2.627, 0.9162144, 7.448361],
#   [22, 'O1', 2.627, 0.0, 8.77],
#   [11, 'O1', 3.9405, 0.59238, 6.5775],
#   [13, 'O1', 1.3135, 0.59238, 6.5775],
#   [17, 'O1', 2.627, 2.46825, 7.872829]],
#  3: [['Si1', 1.0, 2.627, 4.0202856, 7.448361],
#   [12, 'O1', 1.3135, 4.34412, 6.5775],
#   [10, 'O1', 3.9405, 4.34412, 6.5775],
#   [17, 'O1', 2.627, 2.46825, 7.872829],
#   [15, 'O1', 2.627, 4.9365, 8.77]],
#  4: [['Si1', 1.0, 2.627, 8.9567856, 1.321639],
#   [22, 'O1', 2.627, 9.873, 0.0],
#   [18, 'O1', 1.3135, 9.28062, 2.1925],
#   [20, 'O1', 3.9405, 9.28062, 2.1925],
# ...
